# %% [markdown]
# # Introduction
#
# In this session, we will build on your knowledge from the previous class on data gathering and cleaning. Today, we will dive into exploratory data analysis (EDA) and its importance in the financial sector.
# We will be using the LendingClub dataset and perform an exploratory data analysis to uncover actionable insights.
#
#
# ## Agenda:
# 1. Overview of exploratory data analysis
# 2. Summary statistics - Univariate analysis
# 3. Multivariate analysis
# 4. Enriching your data with feature engineering
# 5. Useful data visualisation techniques
# 6. Data standardisation & Normalisation
# 7. Pandas profiling: a great starting point for EDA
# 8. Assignment #1
#
# Demo: Implementation in Python
# ------------------------------

# %% [markdown]
# ### Set up

# %% [markdown]
# #### User-specified parameters

# %%
python_material_folder_name = "python-material"

# %% [markdown]
# #### Import libraries

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Check if in Google Colab environment
try:
    from google.colab import drive
    # Mount drive
    drive.mount('/content/drive')
    # Set up path to Python material parent folder
    path_python_material = rf"drive/MyDrive/{python_material_folder_name}"
        # If unsure, print current directory path by executing the following in a new cell:
        # !pwd
    IN_COLAB = True
except:
    IN_COLAB = False
    # If working locally on Jupyter Notebook, parent folder is one folder up (assuming you are using the folder structure shared at the beginning of the course)
    path_python_material = ".."

# %% [markdown]
# ---
#
# 1\. Overview of data exploration
# ----------------------------------------
# Once you have sourced the relevant data for your project, you need to become familiar with it to:
# - Gain a better understanding of the data's structure and content.
# - Discover patterns, trends, and relationships within the data.
# - Extract actionable insights that can inform business decisions.
#
# In summary, this will help you assess how the data can be used to achieve your business objective.
#
# ---
#
# 2\. Summary statistics - Univariate analysis
# ----------------------------------------
#
# Univariate analysis involves examining a single variable. Common techniques include calculating central tendency measures like mean, median, and mode.
#
# - **Mean**: The average value
# - **Median**: The middle value
# - **Mode**: The most frequent value
# - **Standard Deviation**: Measures the spread of the data
# - **Percentiles**: Indicate the relative standing of a value in the dataset
#
# ### Why are they useful?
# Summary statistics provide a quick overview of the data, allowing us to grasp the general trends and identify any anomalies or outliers.
#
# ### <span style="color:BLUE"> **>>> QUESTION:** </span>
# > *Where have we already encountered descriptive statistics and can you remember how to print some of them out for a pandas dataframe?*

# %% [markdown]
# ### Data import

# %%
# Read data that was exported from previous session
df = pd.read_csv(f"{path_python_material}/data/2-intermediate/df_out_dsif2.csv")

df.head()
# Out:
#           id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0  167338079     4000.0       4000.0           4000.0   36 months   13.08%
# 1   71016917    24000.0      24000.0          24000.0   60 months    9.16%
# 2   39589826     5000.0       5000.0           5000.0   36 months   10.49%
# 3  134798709    24000.0      24000.0          24000.0   60 months   11.05%
# 4  127097355    14000.0      14000.0          14000.0   60 months   13.59%
#
#    installment grade sub_grade       emp_title emp_length home_ownership  \
# 0       134.93     B        B5         cashier  10+ years       MORTGAGE
# 1       500.07     B        B2             ABM    6 years           RENT
# 2       162.49     B        B3          driver  10+ years       MORTGAGE
# 3       522.42     B        B4             NaN        NaN       MORTGAGE
# 4       322.79     C        C2  Shipping Clerk  10+ years       MORTGAGE
#
#    annual_inc verification_status   issue_d loan_status pymnt_plan  \
# 0     48000.0     Source Verified  Mar-2020     Current          n
# 1     57000.0     Source Verified  Feb-2016     Current          n
# 2     55000.0        Not Verified  Jan-2015  Fully Paid          n
# 3     43500.0        Not Verified  Jun-2018     Current          n
# 4     48000.0     Source Verified  Jan-2018  Fully Paid          n
#
#                                                  url             purpose  \
# 0  https://lendingclub.com/browse/loanDetail.acti...    home_improvement
# 1  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 2  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 3  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 4  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
#
#                      title zip_code addr_state    dti  delinq_2yrs  \
# 0         Home improvement    115xx         NY  20.25          1.0
# 1  Credit card refinancing    708xx         LA  25.33          0.0
# 2  Credit card refinancing    347xx         FL   7.22          0.0
# 3       Debt consolidation    443xx         OH  24.55          0.0
# 4       Debt consolidation    681xx         NE  24.30          0.0
#
#   earliest_cr_line  fico_range_low  fico_range_high  inq_last_6mths  \
# 0         Dec-2004           665.0            669.0             0.0
# 1         Jan-2004           680.0            684.0             0.0
# 2         Apr-2010           665.0            669.0             0.0
# 3         Oct-2005           750.0            754.0             0.0
# 4         Apr-2008           735.0            739.0             1.0
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                    19.0                   110.0       4.0      1.0
# 1                     NaN                     NaN      10.0      0.0
# 2                     NaN                    61.0       7.0      1.0
# 3                     NaN                     NaN      15.0      0.0
# 4                     NaN                     NaN      16.0      0.0
#
#    revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0     1988.0      82.8%       12.0                   w    3816.34
# 1    22697.0      64.5%       24.0                   w    4333.29
# 2     6001.0      52.6%        9.0                   f       0.00
# 3     6573.0      12.1%       23.0                   w   16317.69
# 4    11894.0      27.1%       23.0                   w       0.00
#
#    out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0        3816.34    266.950000           266.95           183.66
# 1        4333.29  25496.160000         25496.16         19666.71
# 2           0.00   5846.672836          5846.67          5000.00
# 3       16317.69  12000.930000         12000.93          7682.31
# 4           0.00  16605.680000         16605.68         14000.00
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0          83.29                 0.0         0.0                      0.0
# 1        5829.45                 0.0         0.0                      0.0
# 2         846.67                 0.0         0.0                      0.0
# 3        4318.62                 0.0         0.0                      0.0
# 4        2605.68                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     May-2020           134.93     Jun-2020           May-2020
# 1     May-2020           500.07     Jun-2020           May-2020
# 2     Jan-2018           162.43          NaN           May-2020
# 3     May-2020           522.42     Jun-2020           May-2020
# 4     Jul-2019         11128.82          NaN           Feb-2020
#
#    last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  \
# 0                 669.0                665.0                         1.0
# 1                 704.0                700.0                         0.0
# 2                 789.0                785.0                         0.0
# 3                 749.0                745.0                         0.0
# 4                 779.0                775.0                         0.0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                          NaN          1.0       Individual
# 1                          NaN          1.0       Individual
# 2                          NaN          1.0       Individual
# 3                          NaN          1.0       Individual
# 4                          NaN          1.0       Individual
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                       NaN             0.0
# 1               NaN        NaN                       NaN             0.0
# 2               NaN        NaN                       NaN             0.0
# 3               NaN        NaN                       NaN             0.0
# 4               NaN        NaN                       NaN             0.0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0        3832.0     259024.0          0.0          1.0          0.0
# 1           0.0      61815.0          0.0          3.0          0.0
# 2           0.0     159131.0          NaN          NaN          NaN
# 3           0.0     104590.0          2.0          1.0          0.0
# 4           0.0      90253.0          2.0          2.0          1.0
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          1.0                16.0        9960.0     56.0          0.0
# 1          3.0                14.0       39118.0     72.0          1.0
# 2          NaN                 NaN           NaN      NaN          NaN
# 3          1.0                17.0       11947.0     60.0          2.0
# 4          1.0                 7.0       22953.0     60.0          3.0
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          0.0         0.0      59.0            2400.0     1.0          0.0
# 1          1.0      2137.0      67.0           35200.0     0.0          7.0
# 2          NaN         NaN       NaN           11400.0     NaN          NaN
# 3          3.0      2223.0      25.0           54500.0     2.0          0.0
# 4          4.0      3907.0      43.0           43900.0     1.0          0.0
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           0.0                   1.0      64756.0             NaN      NaN
# 1           0.0                   4.0       6182.0          7741.0     40.5
# 2           NaN                   4.0      22733.0          4521.0     54.8
# 3           2.0                   4.0       6973.0         43140.0     12.0
# 4           2.0                   5.0       5641.0         17318.0     39.9
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                       0.0          0.0               179.0
# 1                       0.0          0.0               145.0
# 2                       0.0          0.0                57.0
# 3                       0.0          0.0                37.0
# 4                       0.0          0.0                72.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                  75.0                   38.0            16.0       2.0
# 1                 137.0                    7.0             7.0       0.0
# 2                  57.0                   14.0             9.0       1.0
# 3                 132.0                    1.0             1.0       2.0
# 4                 117.0                    6.0             6.0       2.0
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                   NaN                      19.0                   16.0
# 1                   7.0                       NaN                   24.0
# 2                  14.0                       NaN                    1.0
# 3                   1.0                       NaN                    3.0
# 4                   6.0                       NaN                    5.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                            19.0                    1.0             0.0
# 1                             NaN                    0.0             3.0
# 2                             NaN                    0.0             3.0
# 3                             NaN                    1.0             6.0
# 4                             NaN                    0.0             4.0
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              2.0          0.0        1.0        5.0            2.0
# 1              5.0          5.0        6.0       15.0            7.0
# 2              5.0          3.0        3.0        2.0            5.0
# 3              7.0         11.0       16.0        2.0           13.0
# 4              5.0          5.0        6.0        5.0           13.0
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0            5.0                  2.0       4.0               0.0
# 1            9.0                  5.0      10.0               0.0
# 2            6.0                  5.0       7.0               0.0
# 3           19.0                  7.0      15.0               0.0
# 4           16.0                  5.0      16.0               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 0.0                 0.0            75.0
# 1           0.0                 0.0                 1.0            95.8
# 2           0.0                 0.0                 1.0           100.0
# 3           0.0                 0.0                 2.0            95.7
# 4           0.0                 0.0                 4.0           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               NaN                   1.0        0.0         395328.0
# 1              60.0                   0.0        0.0          88154.0
# 2              33.3                   0.0        1.0         171118.0
# 3               0.0                   0.0        0.0         202606.0
# 4               0.0                   0.0        0.0         152081.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0            11948.0             0.0                     17928.0
# 1            61815.0         13000.0                     52954.0
# 2            13124.0         10000.0                      7526.0
# 3            18520.0         49000.0                     20000.0
# 4            34847.0         28800.0                     38181.0
#
#    revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
#
#   sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                      NaN                     NaN               NaN
# 1                      NaN                     NaN               NaN
# 2                      NaN                     NaN               NaN
# 3                      NaN                     NaN               NaN
# 4                      NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med hardship_flag hardship_type  \
# 0                                 NaN             N           NaN
# 1                                 NaN             N           NaN
# 2                                 NaN             N           NaN
# 3                                 NaN             N           NaN
# 4                                 NaN             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0             NaN             NaN            NaN              NaN
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                 NaN               NaN                     NaN
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              NaN           NaN                  NaN
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag hardship_status_filled  \
# 0                           NaN                    N            NO_HARDSHIP
# 1                           NaN                    N            NO_HARDSHIP
# 2                           NaN                    N            NO_HARDSHIP
# 3                           NaN                    N            NO_HARDSHIP
# 4                           NaN                    N            NO_HARDSHIP
#
#    last_pymnt_amnt_log  last_pymnt_amnt_capped  loan_id_extracted  \
# 0             4.912140                  134.93          167338079
# 1             6.216746                  500.07           71016917
# 2             5.096385                  162.43           39589826
# 3             6.260384                  522.42          134798709
# 4             9.317383                11128.82          127097355
#
#   emp_title_clean emp_title_manager Job Title Category
# 0         cashier             False       NaN      NaN
# 1             abm             False       NaN      NaN
# 2          driver             False       NaN      NaN
# 3             NaN               NaN       NaN      NaN
# 4  shipping clerk             False       NaN      NaN

# %% [markdown]
# ### Summary Statistics

# %%
from scipy.stats import skew

# Calculating Summary Statistics
mean_loan = df['loan_amnt'].mean()
median_loan = df['loan_amnt'].median()
mode_loan = df['loan_amnt'].mode()[0]
std_loan = df['loan_amnt'].std()
percentiles_loan = df['loan_amnt'].quantile([0.25, 0.5, 0.75])
skewness_value = skew(df['loan_amnt'])

print(f"Mean Loan Amount: {mean_loan}")
print(f"Median Loan Amount: {median_loan}")
print(f"Mode Loan Amount: {mode_loan}")
print(f"Standard Deviation of Loan Amount: {std_loan}")
print(f"Loan Amount Percentiles: \n{percentiles_loan}")
print("Skewness:", skewness_value)
# Out:
# Mean Loan Amount: 15332.373
# Median Loan Amount: 13000.0
# Mode Loan Amount: 10000.0
# Standard Deviation of Loan Amount: 9468.189883370933
# Loan Amount Percentiles:
# 0.25     8000.0
# 0.50    13000.0
# 0.75    20000.0
# Name: loan_amnt, dtype: float64
# Skewness: 0.7887250378394999

# %% [markdown]
# ### <span style="color:BLUE"> **>>> EXERCISE:**</span>
# > Create a function that takes as input a dataframe and a column name, and oututs the summary statistics as per the output created in the cell above (mean, median, mode, std deviation and 25th, 50th and 75th percentiles, skewness value.
#
# > Additionally, based on skewness value print the following:
# 'Skewness = 0: Data is perfectly symmetric.'
# 'Skewness > 0: Positive skew (right skew).'
# 'Skewness < 0: Negative skew (left skew).'
#
# > Test the function on `loan_amnt` column first, then on `int_rate` column. What happens when you run it on `int_rate`, can you think of a way around it?

# %%
# Step 1 - Create the function
def summary_statistics(dataframe:pd.DataFrame, column_name:str):
    mean_loan = dataframe[column_name].mean()
    median_loan = dataframe[column_name].median()
    mode_loan = dataframe[column_name].mode()[0]
    std_loan = dataframe[column_name].std()
    percentiles_loan = dataframe[column_name].quantile([0.25, 0.5, 0.75])
    skewness_value = skew(dataframe[column_name])
    
    print(f"Mean Loan Amount: {mean_loan}")
    print(f"Median Loan Amount: {median_loan}")
    print(f"Mode Loan Amount: {mode_loan}")
    print(f"Standard Deviation of Loan Amount: {std_loan}")
    print(f"Loan Amount Percentiles: \n{percentiles_loan}")
    print("Skewness:", skewness_value)

    if skewness_value == 0:
        print("Skewness = 0: Data is perfectly symmetric.")
    elif skewness_value > 0:
        print("Skewness > 0: Positive skew (right skew).")
    else:
        print("Skewness < 0: Negative skew (left skew).")
        
    print(f"-------------------------------------")

    #    """
    #    Takes as input a dataframe and a column name, and oututs the following summary statistics: mean, median, mode, std deviation and 25th, 50th and 75th percentiles, skewness value and assessment.
    #    """
    # YOUR CODE HERE

# Step 2 - Test on loan_amnt
summary_statistics(df,'loan_amnt')


# Step 3 - Test on int_rate
df['int_rate_clean'] = df['int_rate'].str.rstrip('%').astype('float') / 100.0

summary_statistics(df,'int_rate_clean')
# Out:
# Mean Loan Amount: 15332.373
# Median Loan Amount: 13000.0
# Mode Loan Amount: 10000.0
# Standard Deviation of Loan Amount: 9468.189883370933
# Loan Amount Percentiles:
# 0.25     8000.0
# 0.50    13000.0
# 0.75    20000.0
# Name: loan_amnt, dtype: float64
# Skewness: 0.7887250378394999
# Skewness > 0: Positive skew (right skew).
# -------------------------------------
# Mean Loan Amount: 0.13056737399999999
# Median Loan Amount: 0.1249
# Mode Loan Amount: 0.0819
# Standard Deviation of Loan Amount: 0.048769601321768614
# Loan Amount Percentiles:
# 0.25    0.0917
# 0.50    0.1249
# 0.75    0.1601
# Name: int_rate_clean, dtype: float64
# Skewness: 0.7750035519672701
# Skewness > 0: Positive skew (right skew).
# -------------------------------------

# %% [markdown]
# Hint: to improve format and limit number of decimal characters, try adopting the following syntax instead:
# `mean_loan = ("%.2f" % df[col_name].mean())`

# %% [markdown]
# 3\. Multivariate Analysis
# ----------------------------------------
#
# Multivariate analysis involves examining relationships between two or more variables. This can help identify correlations and interactions within the data.
#
# ### Correlation
# Correlation is a way to measure how strongly two things are related to each other. It's like asking: "When one thing changes, does the other thing change too? And if it does, how much?"
#
# **Note**: correlation tells us about the strength and direction of a relationship between two variables (X and Y), but it doesn't give us the exact amount by which Y changes when X changes.

# %%
# Correlation between Loan Amount and Interest Rate
correlation = df['loan_amnt'].corr(df['int_rate_clean'])
print(f"Correlation between Loan Amount and Interest Rate: {correlation}")
# Out:
# Correlation between Loan Amount and Interest Rate: 0.06635250967803737

# %% [markdown]
# ### <span style="color:BLUE"> **>>> EXERCISE:**  </span>
# > Find the correlation between `loan_amnt` and a new column called `term_numeric` which is a numeric equivalent of the `term` column.

# %%
#df['term'].head()

#df['term'].str.strip(" months") #how to limit output \\ .head(5)

#df['term_numeric'] = df['term'].str.strip(" months").astype("float")
df['term_numeric'] = df['term'].str.strip(" months").astype("float")
correlation_term = df['loan_amnt'].corr(df['term_numeric'])
print(f"Correlation between loan amount and loan term: {correlation_term}")
# Out:
# Correlation between loan amount and loan term: 0.3905709541520238

# %% [markdown]
# ### <span style="color:BLUE"> **>>> DISCUSSION:**  </span>
# > What can we conclude?

# %% [markdown]
# 4\. Enriching your data with feature engineering
# -----------------------
#
# ### What is Feature Engineering?
#
# Feature engineering is the process of using domain knowledge to create new features or modify existing ones to improve the performance of machine learning models.
#
# ### Why is it important?
#
# Feature engineering can significantly enhance the predictive power of models by incorporating additional information or transforming existing data into more useful formats.
#
# ### Techniques
#
# -   **Creating New Features**: e.g., debt-to-income ratio
# -   **Transforming Existing Features**: e.g., log transformation
# -   **Feature encoding**: e.g.: dummy encoding, label encoding

# %%
print(*df.columns, sep=("\n"))
# Out:
# id
# loan_amnt
# funded_amnt
# funded_amnt_inv
# term
# int_rate
# installment
# grade
# sub_grade
# emp_title
# emp_length
# home_ownership
# annual_inc
# verification_status
# issue_d
# loan_status
# pymnt_plan
# url
# purpose
# title
# zip_code
# addr_state
# dti
# delinq_2yrs
# earliest_cr_line
# fico_range_low
# fico_range_high
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# initial_list_status
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_d
# last_pymnt_amnt
# next_pymnt_d
# last_credit_pull_d
# last_fico_range_high
# last_fico_range_low
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# application_type
# annual_inc_joint
# dti_joint
# verification_status_joint
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_act_il
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
# revol_bal_joint
# sec_app_fico_range_low
# sec_app_fico_range_high
# sec_app_earliest_cr_line
# sec_app_inq_last_6mths
# sec_app_mort_acc
# sec_app_open_acc
# sec_app_revol_util
# sec_app_open_act_il
# sec_app_num_rev_accts
# sec_app_chargeoff_within_12_mths
# sec_app_collections_12_mths_ex_med
# hardship_flag
# hardship_type
# hardship_reason
# hardship_status
# deferral_term
# hardship_amount
# hardship_start_date
# hardship_end_date
# payment_plan_start_date
# hardship_length
# hardship_dpd
# hardship_loan_status
# orig_projected_additional_accrued_interest
# hardship_payoff_balance_amount
# hardship_last_payment_amount
# debt_settlement_flag
# hardship_status_filled
# last_pymnt_amnt_log
# last_pymnt_amnt_capped
# loan_id_extracted
# emp_title_clean
# emp_title_manager
# Job Title
# Category
# int_rate_clean
# term_numeric

# %% [markdown]
# ## Creating new features

# %%
# Creating a new feature: debt-to-income ratio
df['debt_to_income'] = df['loan_amnt'] / df['annual_inc']
df[['id','loan_amnt', 'annual_inc', 'debt_to_income']].head(5)
# Out:
#           id  loan_amnt  annual_inc  debt_to_income
# 0  167338079     4000.0     48000.0        0.083333
# 1   71016917    24000.0     57000.0        0.421053
# 2   39589826     5000.0     55000.0        0.090909
# 3  134798709    24000.0     43500.0        0.551724
# 4  127097355    14000.0     48000.0        0.291667

# %% [markdown]
# ### <span style="color:BLUE"> **>>> EXERCISE:**  </span>
# > Let's create a new feature called `interest_per_loan_amnt`, which calculates the total interest paid throughout the course of the term based on interest rate, loan amount and term information.

# %%
df['interest_per_loan_amnt'] = df['loan_amnt'] * (df['int_rate_clean'] / 100) * (df['term_numeric'] / 12)

# Printing out results
df[['id','loan_amnt', 'int_rate_clean', 'term_numeric', 'interest_per_loan_amnt']].head()
# Out:
#           id  loan_amnt  int_rate_clean  term_numeric  interest_per_loan_amnt
# 0  167338079     4000.0          0.1308          36.0                  15.696
# 1   71016917    24000.0          0.0916          60.0                 109.920
# 2   39589826     5000.0          0.1049          36.0                  15.735
# 3  134798709    24000.0          0.1105          60.0                 132.600
# 4  127097355    14000.0          0.1359          60.0                  95.130

# %% [markdown]
# ## Transforming Existing Features
# ### Example: Log transformation
# Log transformation is a technique used to handle skewed data. It involves applying the natural logarithm (or another logarithm) to the data to reduce skewness and stabilize variance.
#
# **Why is this important?**
# Skewed data can distort statistical analyses and machine learning models, leading to poor predictions. Log transformation can help normalize the data, making it more suitable for analysis.
# Many financial variables, such as income or loan amounts, can have long-tailed distributions. By applying log transformations, we ensure that these features are better suited for linear models and improve the model’s performance.

# %%
import matplotlib.pyplot as plt

# Log transformation
df['loan_amnt_log'] = np.log(df['loan_amnt'] + 1) # Adding +1 to avoid log(0)

# Plotting original and log-transformed data
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(df['loan_amnt'], bins=10, color='blue', edgecolor='black')
plt.title('Original data')

plt.subplot(1, 2, 2)
plt.hist(df['loan_amnt_log'], bins=10, color='green', edgecolor='black')
plt.title('Log-transformed data')

plt.show()

print(f"Skewness before log transform: {skew(df['loan_amnt'])}")
print(f"Skewness after log transform: {skew(df['loan_amnt_log'])}")
# Out:
# Skewness before log transform: 0.7887250378394999
# Skewness after log transform: -0.6505299680118821

# %% [markdown]
# ## Feature encoding
# **Categorical feature encoding** is a crucial step in preparing categorical data for use in machine learning models. Categorical data includes variables that represent discrete categories or groups, such as "loan grade," "employment status," or "credit rating." Unlike numerical data, these categories do not have an inherent order or scale that algorithms can directly interpret. Therefore, we need to convert these categories into a numerical format that can be utilized by machine learning models.
#
# ### Dummy Encoding (One-Hot Encoding)
#
# **Dummy Encoding** (or One-Hot Encoding) converts each category of a categorical variable into a new binary column (0 or 1). Each column represents a category, with a value of `1` indicating the presence of that category in the observation, and `0` otherwise.
#
# **Why is this important?**
# Machine learning algorithms generally require numerical input. Without converting categorical data into numerical form, algorithms wouldn't be able to process the data, leading to errors.
#
# By using dummy encoding, you preserve the distinct nature of each category without implying any order or rank between them. This is especially important for models like linear regression, where numerical values can suggest a relationship or order that does not actually exist.

# %%
# One-hot encoding
df_dummies = pd.get_dummies(df['grade'], prefix='grade')
df_dummies.head()
# Out:
#    grade_A  grade_B  grade_C  grade_D  grade_E  grade_F  grade_G
# 0    False     True    False    False    False    False    False
# 1    False     True    False    False    False    False    False
# 2    False     True    False    False    False    False    False
# 3    False     True    False    False    False    False    False
# 4    False    False     True    False    False    False    False

# %% [markdown]
# ### Label Encoding
# Label Encoding assigns a unique integer to each category in the categorical variable. For example, a "loan grade" of 'A' might be encoded as `0`, 'B' as `1`, and so on.
#
# **Why is this important?**: Label encoding is useful when the categorical variable is ordinal (i.e., there is a meaningful order or ranking to the categories). However, for non-ordinal data, it might imply an order that does not exist, potentially misleading the model.
# This method is simple and works well when you need to convert a categorical variable with many levels into a numerical format quickly. However, be careful not to unintentionally introduce ordinal relationships when none exist.

# %%
from sklearn.preprocessing import LabelEncoder

# Label encoding
le = LabelEncoder()
df['grade_encoded'] = le.fit_transform(df['grade'])
df[['grade', 'grade_encoded']].head()
# Out:
#   grade  grade_encoded
# 0     B              1
# 1     B              1
# 2     B              1
# 3     B              1
# 4     C              2

# %% [markdown]
# 5\. Useful data visualisation techniques
# ----------------------
# ### Why is Visualization Important?
#
# Visualization helps in understanding data patterns and communicating findings effectively. Common visualization techniques include:
#
# -   **Histograms**: To visualize distributions
# -   **Box Plots**: To identify outliers
# -   **Bar Plots**: To compare categories
# -   **Pair Plots**: To explore relationships between pairs of variables
# -   **Heatmaps**: To visualize correlations
# -   **Violin Plots**: To combine density and summary statistics
#
# Check out the [seaborn cheat sheet](https://www.datacamp.com/cheat-sheet/python-seaborn-cheat-sheet) for more info.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram of Loan Amount
plt.figure(figsize=(8, 6))
sns.histplot(df['loan_amnt'], kde=True)
plt.title('Distribution of Loan Amount')
plt.show()

# %%
# Box Plot of Interest Rate
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['int_rate_clean'])
plt.title('Box Plot of Interest Rate',)
plt.show()

# %%
# Select numeric columns only
df_numeric = df.select_dtypes(exclude="object")

# Heatmap of Correlations
plt.figure(figsize=(8, 6))
sns.heatmap(df_numeric.corr(), annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Hard to read? Absolutely, this is because too many columns are selected. Let's try on a subset of columns:

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df_numeric \
            .drop(columns=df_numeric.columns[10:]) \
            .corr(), annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap')
plt.show()

# %%
df_numeric.corr().head(2)
# Out:
#                  id  loan_amnt  funded_amnt  funded_amnt_inv  installment  \
# id         1.000000   0.069585     0.070426         0.072644     0.053122
# loan_amnt  0.069585   1.000000     0.999829         0.999297     0.943736
#
#            annual_inc       dti  delinq_2yrs  fico_range_low  fico_range_high  \
# id           0.048110  0.063316    -0.034642        0.136056         0.136056
# loan_amnt    0.249457  0.049319    -0.012540        0.114610         0.114609
#
#            inq_last_6mths  mths_since_last_delinq  mths_since_last_record  \
# id              -0.133213                0.043742                0.200579
# loan_amnt       -0.035071               -0.012170                0.054270
#
#            open_acc   pub_rec  revol_bal  total_acc  out_prncp  out_prncp_inv  \
# id         0.021417 -0.053769   0.014232  -0.071945   0.544619       0.544578
# loan_amnt  0.174131 -0.058210   0.332163   0.185355   0.449608       0.449634
#
#            total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# id           -0.352441        -0.350387        -0.339494      -0.225023
# loan_amnt     0.670850         0.670918         0.602905       0.580429
#
#            total_rec_late_fee  recoveries  collection_recovery_fee  \
# id                  -0.018769   -0.095589                -0.083260
# loan_amnt            0.073851    0.125247                 0.122159
#
#            last_pymnt_amnt  last_fico_range_high  last_fico_range_low  \
# id               -0.143228              0.162942             0.137961
# loan_amnt         0.321460              0.091484             0.074173
#
#            collections_12_mths_ex_med  mths_since_last_major_derog  \
# id                           0.010252                     0.059458
# loan_amnt                   -0.022780                     0.009908
#
#            policy_code  annual_inc_joint  dti_joint  acc_now_delinq  \
# id                 NaN          0.128854   0.025444       -0.034081
# loan_amnt          NaN          0.337498   0.068489       -0.003170
#
#            tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# id            -0.009590     0.033323    -0.027496     0.009857     0.010047
# loan_amnt     -0.027866     0.302120    -0.026345     0.038293    -0.013346
#
#            open_il_24m  mths_since_rcnt_il  total_bal_il   il_util  \
# id            0.014706           -0.041991      0.032237 -0.032800
# loan_amnt     0.011058           -0.003917      0.146680 -0.086866
#
#            open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  \
# id           -0.050097    -0.071754    0.045203 -0.099453          0.105515
# loan_amnt    -0.047617    -0.041825    0.397554  0.010775          0.351375
#
#              inq_fi  total_cu_tl  inq_last_12m  acc_open_past_24mths  \
# id         0.063510     0.005264     -0.037439             -0.002395
# loan_amnt -0.013138     0.073439      0.007788             -0.010377
#
#            avg_cur_bal  bc_open_to_buy   bc_util  chargeoff_within_12_mths  \
# id            0.020468        0.170281 -0.208100                 -0.003450
# loan_amnt     0.223601        0.210893  0.050059                 -0.010581
#
#            delinq_amnt  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  \
# id           -0.006454           -0.015531             -0.045247
# loan_amnt    -0.000794            0.121312              0.163270
#
#            mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# id                      0.051984        0.019530 -0.092087
# loan_amnt               0.054319        0.033921  0.212047
#
#            mths_since_recent_bc  mths_since_recent_bc_dlq  \
# id                     0.009149                 -0.007669
# loan_amnt              0.037632                 -0.039722
#
#            mths_since_recent_inq  mths_since_recent_revol_delinq  \
# id                      0.036017                        0.024855
# loan_amnt               0.000697                       -0.025062
#
#            num_accts_ever_120_pd  num_actv_bc_tl  num_actv_rev_tl  \
# id                     -0.000679        0.001238        -0.042931
# loan_amnt              -0.061542        0.189939         0.147701
#
#            num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  num_rev_accts  \
# id            0.041326  -0.114559   0.010253      -0.004339      -0.108981
# loan_amnt     0.207458   0.183298   0.079591       0.153224       0.147777
#
#            num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  num_tl_30dpd  \
# id                   -0.042993  0.008497         -0.014395     -0.032610
# loan_amnt             0.147874  0.172722         -0.000485     -0.002693
#
#            num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# id                  -0.021964           -0.002420        0.016120
# loan_amnt           -0.027142           -0.033423        0.096753
#
#            percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# id                -0.200527             -0.006617  -0.045211         0.057603
# loan_amnt          0.021491             -0.075838   0.000663         0.332667
#
#            total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# id                  0.059995        0.135620                    0.079815
# loan_amnt           0.274361        0.371336                    0.208203
#
#            revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# id                0.093864                0.122376                 0.122370
# loan_amnt         0.357975                0.189948                 0.189951
#
#            sec_app_inq_last_6mths  sec_app_mort_acc  sec_app_open_acc  \
# id                      -0.011803          0.034437          0.010775
# loan_amnt               -0.064526          0.205193          0.215891
#
#            sec_app_revol_util  sec_app_open_act_il  sec_app_num_rev_accts  \
# id                  -0.119915             0.018829              -0.002188
# loan_amnt            0.053532             0.066514               0.202099
#
#            sec_app_chargeoff_within_12_mths  \
# id                                -0.024635
# loan_amnt                         -0.049006
#
#            sec_app_collections_12_mths_ex_med  deferral_term  hardship_amount  \
# id                                  -0.038806      -0.254557        -0.092709
# loan_amnt                           -0.073756       0.035086         0.184514
#
#            hardship_length  hardship_dpd  \
# id               -0.254557     -0.384734
# loan_amnt         0.035086     -0.007080
#
#            orig_projected_additional_accrued_interest  \
# id                                           0.206790
# loan_amnt                                    0.452079
#
#            hardship_payoff_balance_amount  hardship_last_payment_amount  \
# id                               0.368004                      0.032225
# loan_amnt                        0.776098                      0.173541
#
#            last_pymnt_amnt_log  last_pymnt_amnt_capped  loan_id_extracted  \
# id                   -0.264386               -0.176699           1.000000
# loan_amnt             0.164731                0.278321           0.069585
#
#            int_rate_clean  term_numeric  debt_to_income  \
# id              -0.044850      0.024468        0.001342
# loan_amnt        0.066353      0.390571        0.005048
#
#            interest_per_loan_amnt  loan_amnt_log  grade_encoded
# id                       0.015793       0.034738      -0.178865
# loan_amnt                0.740174       0.921521       0.061902

# %%
# How to use or interpret? 

df_to_iterate = df_numeric.corr()
    
# Iterate through each numeric column in the dataframe
for column in df_to_iterate.columns:
    # Sort the values in descending order and take the top 3
    top_3_values = df_to_iterate[column].nlargest(3)
    print(f"Top 3 values for column '{column}':\n{top_3_values}\n")
# Out:
# Top 3 values for column 'id':
# id                   1.000000
# loan_id_extracted    1.000000
# out_prncp            0.544619
# Name: id, dtype: float64
#
# Top 3 values for column 'loan_amnt':
# loan_amnt          1.000000
# funded_amnt        0.999829
# funded_amnt_inv    0.999297
# Name: loan_amnt, dtype: float64
#
# Top 3 values for column 'funded_amnt':
# funded_amnt        1.000000
# loan_amnt          0.999829
# funded_amnt_inv    0.999510
# Name: funded_amnt, dtype: float64
#
# Top 3 values for column 'funded_amnt_inv':
# funded_amnt_inv    1.000000
# funded_amnt        0.999510
# loan_amnt          0.999297
# Name: funded_amnt_inv, dtype: float64
#
# Top 3 values for column 'installment':
# installment    1.000000
# funded_amnt    0.943976
# loan_amnt      0.943736
# Name: installment, dtype: float64
#
# Top 3 values for column 'annual_inc':
# annual_inc          1.000000
# annual_inc_joint    0.717859
# tot_hi_cred_lim     0.348756
# Name: annual_inc, dtype: float64
#
# Top 3 values for column 'dti':
# dti               1.000000
# debt_to_income    0.357195
# dti_joint         0.242936
# Name: dti, dtype: float64
#
# Top 3 values for column 'delinq_2yrs':
# delinq_2yrs              1.000000
# num_tl_90g_dpd_24m       0.649153
# num_accts_ever_120_pd    0.204940
# Name: delinq_2yrs, dtype: float64
#
# Top 3 values for column 'fico_range_low':
# fico_range_low     1.000000
# fico_range_high    1.000000
# bc_open_to_buy     0.503754
# Name: fico_range_low, dtype: float64
#
# Top 3 values for column 'fico_range_high':
# fico_range_high    1.000000
# fico_range_low     1.000000
# bc_open_to_buy     0.503764
# Name: fico_range_high, dtype: float64
#
# Top 3 values for column 'inq_last_6mths':
# inq_last_6mths    1.000000
# inq_last_12m      0.480486
# open_acc_6m       0.444883
# Name: inq_last_6mths, dtype: float64
#
# Top 3 values for column 'mths_since_last_delinq':
# mths_since_last_delinq            1.000000
# mths_since_recent_revol_delinq    0.864339
# mths_since_recent_bc_dlq          0.774304
# Name: mths_since_last_delinq, dtype: float64
#
# Top 3 values for column 'mths_since_last_record':
# mths_since_last_record    1.000000
# fico_range_low            0.302539
# fico_range_high           0.302539
# Name: mths_since_last_record, dtype: float64
#
# Top 3 values for column 'open_acc':
# open_acc         1.000000
# num_sats         0.999141
# num_op_rev_tl    0.841312
# Name: open_acc, dtype: float64
#
# Top 3 values for column 'pub_rec':
# pub_rec                 1.000000
# tax_liens               0.700103
# pub_rec_bankruptcies    0.667397
# Name: pub_rec, dtype: float64
#
# Top 3 values for column 'revol_bal':
# revol_bal           1.000000
# total_rev_hi_lim    0.787893
# max_bal_bc          0.576966
# Name: revol_bal, dtype: float64
#
# Top 3 values for column 'total_acc':
# total_acc        1.000000
# num_rev_accts    0.762623
# open_acc         0.720230
# Name: total_acc, dtype: float64
#
# Top 3 values for column 'out_prncp':
# out_prncp                         1.000000
# out_prncp_inv                     0.999998
# hardship_payoff_balance_amount    0.928240
# Name: out_prncp, dtype: float64
#
# Top 3 values for column 'out_prncp_inv':
# out_prncp_inv                     1.000000
# out_prncp                         0.999998
# hardship_payoff_balance_amount    0.928250
# Name: out_prncp_inv, dtype: float64
#
# Top 3 values for column 'total_pymnt':
# total_pymnt        1.000000
# total_pymnt_inv    0.999566
# total_rec_prncp    0.966945
# Name: total_pymnt, dtype: float64
#
# Top 3 values for column 'total_pymnt_inv':
# total_pymnt_inv    1.000000
# total_pymnt        0.999566
# total_rec_prncp    0.966459
# Name: total_pymnt_inv, dtype: float64
#
# Top 3 values for column 'total_rec_prncp':
# total_rec_prncp    1.000000
# total_pymnt        0.966945
# total_pymnt_inv    0.966459
# Name: total_rec_prncp, dtype: float64
#
# Top 3 values for column 'total_rec_int':
# total_rec_int             1.000000
# interest_per_loan_amnt    0.737528
# total_pymnt               0.705522
# Name: total_rec_int, dtype: float64
#
# Top 3 values for column 'total_rec_late_fee':
# total_rec_late_fee    1.000000
# hardship_dpd          0.303680
# deferral_term         0.142307
# Name: total_rec_late_fee, dtype: float64
#
# Top 3 values for column 'recoveries':
# recoveries                 1.000000
# collection_recovery_fee    0.985689
# hardship_dpd               0.287018
# Name: recoveries, dtype: float64
#
# Top 3 values for column 'collection_recovery_fee':
# collection_recovery_fee    1.000000
# recoveries                 0.985689
# hardship_dpd               0.283818
# Name: collection_recovery_fee, dtype: float64
#
# Top 3 values for column 'last_pymnt_amnt':
# last_pymnt_amnt                 1.000000
# last_pymnt_amnt_capped          0.964173
# hardship_last_payment_amount    0.767869
# Name: last_pymnt_amnt, dtype: float64
#
# Top 3 values for column 'last_fico_range_high':
# last_fico_range_high    1.000000
# last_fico_range_low     0.845760
# fico_range_low          0.389984
# Name: last_fico_range_high, dtype: float64
#
# Top 3 values for column 'last_fico_range_low':
# last_fico_range_low     1.000000
# last_fico_range_high    0.845760
# fico_range_low          0.283765
# Name: last_fico_range_low, dtype: float64
#
# Top 3 values for column 'collections_12_mths_ex_med':
# collections_12_mths_ex_med            1.000000
# num_tl_90g_dpd_24m                    0.110998
# sec_app_collections_12_mths_ex_med    0.081229
# Name: collections_12_mths_ex_med, dtype: float64
#
# Top 3 values for column 'mths_since_last_major_derog':
# mths_since_last_major_derog    1.000000
# mths_since_last_delinq         0.710963
# mths_since_recent_bc_dlq       0.593228
# Name: mths_since_last_major_derog, dtype: float64
#
# Top 3 values for column 'policy_code':
# id            NaN
# loan_amnt     NaN
# funded_amnt   NaN
# Name: policy_code, dtype: float64
#
# Top 3 values for column 'annual_inc_joint':
# annual_inc_joint    1.000000
# annual_inc          0.717859
# revol_bal_joint     0.562830
# Name: annual_inc_joint, dtype: float64
#
# Top 3 values for column 'dti_joint':
# dti_joint           1.000000
# revol_bal_joint     0.379734
# sec_app_open_acc    0.344827
# Name: dti_joint, dtype: float64
#
# Top 3 values for column 'acc_now_delinq':
# acc_now_delinq      1.000000
# num_tl_30dpd        0.815866
# num_tl_120dpd_2m    0.351533
# Name: acc_now_delinq, dtype: float64
#
# Top 3 values for column 'tot_coll_amt':
# tot_coll_amt                  1.000000
# num_accts_ever_120_pd         0.109195
# collections_12_mths_ex_med    0.065056
# Name: tot_coll_amt, dtype: float64
#
# Top 3 values for column 'tot_cur_bal':
# tot_cur_bal        1.000000
# tot_hi_cred_lim    0.982790
# avg_cur_bal        0.823616
# Name: tot_cur_bal, dtype: float64
#
# Top 3 values for column 'open_acc_6m':
# open_acc_6m           1.000000
# num_tl_op_past_12m    0.726367
# open_rv_12m           0.614963
# Name: open_acc_6m, dtype: float64
#
# Top 3 values for column 'open_act_il':
# open_act_il                   1.000000
# num_il_tl                     0.640015
# total_il_high_credit_limit    0.559325
# Name: open_act_il, dtype: float64
#
# Top 3 values for column 'open_il_12m':
# open_il_12m           1.000000
# open_il_24m           0.754662
# num_tl_op_past_12m    0.566733
# Name: open_il_12m, dtype: float64
#
# Top 3 values for column 'open_il_24m':
# open_il_24m             1.000000
# open_il_12m             0.754662
# acc_open_past_24mths    0.577473
# Name: open_il_24m, dtype: float64
#
# Top 3 values for column 'mths_since_rcnt_il':
# mths_since_rcnt_il       1.000000
# mo_sin_rcnt_tl           0.358250
# mths_since_recent_inq    0.113693
# Name: mths_since_rcnt_il, dtype: float64
#
# Top 3 values for column 'total_bal_il':
# total_bal_il                  1.000000
# total_il_high_credit_limit    0.951334
# total_bal_ex_mort             0.907029
# Name: total_bal_il, dtype: float64
#
# Top 3 values for column 'il_util':
# il_util        1.000000
# all_util       0.549777
# open_il_12m    0.332103
# Name: il_util, dtype: float64
#
# Top 3 values for column 'open_rv_12m':
# open_rv_12m           1.000000
# num_tl_op_past_12m    0.836438
# open_rv_24m           0.784631
# Name: open_rv_12m, dtype: float64
#
# Top 3 values for column 'open_rv_24m':
# open_rv_24m             1.000000
# acc_open_past_24mths    0.842752
# open_rv_12m             0.784631
# Name: open_rv_24m, dtype: float64
#
# Top 3 values for column 'max_bal_bc':
# max_bal_bc        1.000000
# revol_bal         0.576966
# total_bc_limit    0.551510
# Name: max_bal_bc, dtype: float64
#
# Top 3 values for column 'all_util':
# all_util    1.000000
# bc_util     0.612917
# il_util     0.549777
# Name: all_util, dtype: float64
#
# Top 3 values for column 'total_rev_hi_lim':
# total_rev_hi_lim    1.000000
# total_bc_limit      0.814139
# revol_bal           0.787893
# Name: total_rev_hi_lim, dtype: float64
#
# Top 3 values for column 'inq_fi':
# inq_fi          1.000000
# inq_last_12m    0.549184
# open_il_24m     0.415613
# Name: inq_fi, dtype: float64
#
# Top 3 values for column 'total_cu_tl':
# total_cu_tl    1.000000
# num_il_tl      0.308990
# total_acc      0.301714
# Name: total_cu_tl, dtype: float64
#
# Top 3 values for column 'inq_last_12m':
# inq_last_12m      1.000000
# inq_fi            0.549184
# inq_last_6mths    0.480486
# Name: inq_last_12m, dtype: float64
#
# Top 3 values for column 'acc_open_past_24mths':
# acc_open_past_24mths    1.000000
# open_rv_24m             0.842752
# num_tl_op_past_12m      0.770087
# Name: acc_open_past_24mths, dtype: float64
#
# Top 3 values for column 'avg_cur_bal':
# avg_cur_bal        1.000000
# tot_cur_bal        0.823616
# tot_hi_cred_lim    0.787830
# Name: avg_cur_bal, dtype: float64
#
# Top 3 values for column 'bc_open_to_buy':
# bc_open_to_buy      1.000000
# total_bc_limit      0.856150
# total_rev_hi_lim    0.680142
# Name: bc_open_to_buy, dtype: float64
#
# Top 3 values for column 'bc_util':
# bc_util             1.000000
# percent_bc_gt_75    0.848557
# all_util            0.612917
# Name: bc_util, dtype: float64
#
# Top 3 values for column 'chargeoff_within_12_mths':
# chargeoff_within_12_mths    1.000000
# num_tl_90g_dpd_24m          0.225957
# delinq_2yrs                 0.150087
# Name: chargeoff_within_12_mths, dtype: float64
#
# Top 3 values for column 'delinq_amnt':
# delinq_amnt         1.000000
# num_tl_120dpd_2m    0.364827
# acc_now_delinq      0.179609
# Name: delinq_amnt, dtype: float64
#
# Top 3 values for column 'mo_sin_old_il_acct':
# mo_sin_old_il_acct    1.000000
# num_il_tl             0.363468
# total_acc             0.348389
# Name: mo_sin_old_il_acct, dtype: float64
#
# Top 3 values for column 'mo_sin_old_rev_tl_op':
# mo_sin_old_rev_tl_op    1.000000
# num_rev_accts           0.342793
# num_bc_tl               0.296426
# Name: mo_sin_old_rev_tl_op, dtype: float64
#
# Top 3 values for column 'mo_sin_rcnt_rev_tl_op':
# mo_sin_rcnt_rev_tl_op    1.000000
# mths_since_recent_bc     0.626672
# mo_sin_rcnt_tl           0.593867
# Name: mo_sin_rcnt_rev_tl_op, dtype: float64
#
# Top 3 values for column 'mo_sin_rcnt_tl':
# mo_sin_rcnt_tl           1.000000
# mo_sin_rcnt_rev_tl_op    0.593867
# mths_since_recent_bc     0.375839
# Name: mo_sin_rcnt_tl, dtype: float64
#
# Top 3 values for column 'mort_acc':
# mort_acc            1.000000
# sec_app_mort_acc    0.701879
# tot_hi_cred_lim     0.554435
# Name: mort_acc, dtype: float64
#
# Top 3 values for column 'mths_since_recent_bc':
# mths_since_recent_bc     1.000000
# mo_sin_rcnt_rev_tl_op    0.626672
# mo_sin_rcnt_tl           0.375839
# Name: mths_since_recent_bc, dtype: float64
#
# Top 3 values for column 'mths_since_recent_bc_dlq':
# mths_since_recent_bc_dlq          1.000000
# mths_since_recent_revol_delinq    0.896744
# mths_since_last_delinq            0.774304
# Name: mths_since_recent_bc_dlq, dtype: float64
#
# Top 3 values for column 'mths_since_recent_inq':
# mths_since_recent_inq    1.000000
# mo_sin_rcnt_tl           0.275384
# mo_sin_rcnt_rev_tl_op    0.156854
# Name: mths_since_recent_inq, dtype: float64
#
# Top 3 values for column 'mths_since_recent_revol_delinq':
# mths_since_recent_revol_delinq    1.000000
# mths_since_recent_bc_dlq          0.896744
# mths_since_last_delinq            0.864339
# Name: mths_since_recent_revol_delinq, dtype: float64
#
# Top 3 values for column 'num_accts_ever_120_pd':
# num_accts_ever_120_pd    1.000000
# num_tl_90g_dpd_24m       0.298789
# delinq_2yrs              0.204940
# Name: num_accts_ever_120_pd, dtype: float64
#
# Top 3 values for column 'num_actv_bc_tl':
# num_actv_bc_tl     1.000000
# num_bc_sats        0.835151
# num_actv_rev_tl    0.832034
# Name: num_actv_bc_tl, dtype: float64
#
# Top 3 values for column 'num_actv_rev_tl':
# num_actv_rev_tl        1.000000
# num_rev_tl_bal_gt_0    0.986393
# num_actv_bc_tl         0.832034
# Name: num_actv_rev_tl, dtype: float64
#
# Top 3 values for column 'num_bc_sats':
# num_bc_sats       1.000000
# num_actv_bc_tl    0.835151
# num_op_rev_tl     0.781121
# Name: num_bc_sats, dtype: float64
#
# Top 3 values for column 'num_bc_tl':
# num_bc_tl        1.000000
# num_rev_accts    0.840402
# num_bc_sats      0.763022
# Name: num_bc_tl, dtype: float64
#
# Top 3 values for column 'num_il_tl':
# num_il_tl      1.000000
# total_acc      0.698240
# open_act_il    0.640015
# Name: num_il_tl, dtype: float64
#
# Top 3 values for column 'num_op_rev_tl':
# num_op_rev_tl    1.000000
# open_acc         0.841312
# num_sats         0.840640
# Name: num_op_rev_tl, dtype: float64
#
# Top 3 values for column 'num_rev_accts':
# num_rev_accts    1.000000
# num_bc_tl        0.840402
# num_op_rev_tl    0.799619
# Name: num_rev_accts, dtype: float64
#
# Top 3 values for column 'num_rev_tl_bal_gt_0':
# num_rev_tl_bal_gt_0    1.000000
# num_actv_rev_tl        0.986393
# num_actv_bc_tl         0.826575
# Name: num_rev_tl_bal_gt_0, dtype: float64
#
# Top 3 values for column 'num_sats':
# num_sats         1.000000
# open_acc         0.999141
# num_op_rev_tl    0.840640
# Name: num_sats, dtype: float64
#
# Top 3 values for column 'num_tl_120dpd_2m':
# num_tl_120dpd_2m    1.000000
# delinq_amnt         0.364827
# acc_now_delinq      0.351533
# Name: num_tl_120dpd_2m, dtype: float64
#
# Top 3 values for column 'num_tl_30dpd':
# num_tl_30dpd      1.000000
# acc_now_delinq    0.815866
# delinq_2yrs       0.094667
# Name: num_tl_30dpd, dtype: float64
#
# Top 3 values for column 'num_tl_90g_dpd_24m':
# num_tl_90g_dpd_24m       1.000000
# delinq_2yrs              0.649153
# num_accts_ever_120_pd    0.298789
# Name: num_tl_90g_dpd_24m, dtype: float64
#
# Top 3 values for column 'num_tl_op_past_12m':
# num_tl_op_past_12m      1.000000
# open_rv_12m             0.836438
# acc_open_past_24mths    0.770087
# Name: num_tl_op_past_12m, dtype: float64
#
# Top 3 values for column 'pct_tl_nvr_dlq':
# pct_tl_nvr_dlq     1.000000
# fico_range_low     0.311128
# fico_range_high    0.311123
# Name: pct_tl_nvr_dlq, dtype: float64
#
# Top 3 values for column 'percent_bc_gt_75':
# percent_bc_gt_75    1.000000
# bc_util             0.848557
# all_util            0.505007
# Name: percent_bc_gt_75, dtype: float64
#
# Top 3 values for column 'pub_rec_bankruptcies':
# pub_rec_bankruptcies      1.000000
# pub_rec                   0.667397
# mths_since_last_record    0.262555
# Name: pub_rec_bankruptcies, dtype: float64
#
# Top 3 values for column 'tax_liens':
# tax_liens       1.000000
# pub_rec         0.700103
# hardship_dpd    0.053257
# Name: tax_liens, dtype: float64
#
# Top 3 values for column 'tot_hi_cred_lim':
# tot_hi_cred_lim    1.00000
# tot_cur_bal        0.98279
# avg_cur_bal        0.78783
# Name: tot_hi_cred_lim, dtype: float64
#
# Top 3 values for column 'total_bal_ex_mort':
# total_bal_ex_mort             1.000000
# total_bal_il                  0.907029
# total_il_high_credit_limit    0.888042
# Name: total_bal_ex_mort, dtype: float64
#
# Top 3 values for column 'total_bc_limit':
# total_bc_limit      1.000000
# bc_open_to_buy      0.856150
# total_rev_hi_lim    0.814139
# Name: total_bc_limit, dtype: float64
#
# Top 3 values for column 'total_il_high_credit_limit':
# total_il_high_credit_limit    1.000000
# total_bal_il                  0.951334
# total_bal_ex_mort             0.888042
# Name: total_il_high_credit_limit, dtype: float64
#
# Top 3 values for column 'revol_bal_joint':
# revol_bal_joint     1.000000
# annual_inc_joint    0.562830
# revol_bal           0.535877
# Name: revol_bal_joint, dtype: float64
#
# Top 3 values for column 'sec_app_fico_range_low':
# sec_app_fico_range_low     1.000000
# sec_app_fico_range_high    1.000000
# fico_range_low             0.461394
# Name: sec_app_fico_range_low, dtype: float64
#
# Top 3 values for column 'sec_app_fico_range_high':
# sec_app_fico_range_high    1.000000
# sec_app_fico_range_low     1.000000
# fico_range_low             0.461397
# Name: sec_app_fico_range_high, dtype: float64
#
# Top 3 values for column 'sec_app_inq_last_6mths':
# sec_app_inq_last_6mths    1.000000
# inq_last_6mths            0.323628
# sec_app_num_rev_accts     0.201283
# Name: sec_app_inq_last_6mths, dtype: float64
#
# Top 3 values for column 'sec_app_mort_acc':
# sec_app_mort_acc    1.000000
# mort_acc            0.701879
# tot_cur_bal         0.407029
# Name: sec_app_mort_acc, dtype: float64
#
# Top 3 values for column 'sec_app_open_acc':
# sec_app_open_acc         1.000000
# sec_app_num_rev_accts    0.747474
# sec_app_open_act_il      0.587691
# Name: sec_app_open_acc, dtype: float64
#
# Top 3 values for column 'sec_app_revol_util':
# sec_app_revol_util    1.000000
# bc_util               0.515908
# percent_bc_gt_75      0.478590
# Name: sec_app_revol_util, dtype: float64
#
# Top 3 values for column 'sec_app_open_act_il':
# sec_app_open_act_il    1.000000
# sec_app_open_acc       0.587691
# dti_joint              0.256440
# Name: sec_app_open_act_il, dtype: float64
#
# Top 3 values for column 'sec_app_num_rev_accts':
# sec_app_num_rev_accts    1.000000
# sec_app_open_acc         0.747474
# num_rev_accts            0.411386
# Name: sec_app_num_rev_accts, dtype: float64
#
# Top 3 values for column 'sec_app_chargeoff_within_12_mths':
# sec_app_chargeoff_within_12_mths      1.000000
# sec_app_collections_12_mths_ex_med    0.372196
# deferral_term                         0.102064
# Name: sec_app_chargeoff_within_12_mths, dtype: float64
#
# Top 3 values for column 'sec_app_collections_12_mths_ex_med':
# sec_app_collections_12_mths_ex_med    1.000000
# sec_app_chargeoff_within_12_mths      0.372196
# collections_12_mths_ex_med            0.081229
# Name: sec_app_collections_12_mths_ex_med, dtype: float64
#
# Top 3 values for column 'deferral_term':
# deferral_term                                 1.000000
# hardship_length                               1.000000
# orig_projected_additional_accrued_interest    0.428871
# Name: deferral_term, dtype: float64
#
# Top 3 values for column 'hardship_amount':
# hardship_amount        1.000000
# last_pymnt_amnt_log    0.666566
# hardship_dpd           0.413592
# Name: hardship_amount, dtype: float64
#
# Top 3 values for column 'hardship_length':
# deferral_term                                 1.000000
# hardship_length                               1.000000
# orig_projected_additional_accrued_interest    0.428871
# Name: hardship_length, dtype: float64
#
# Top 3 values for column 'hardship_dpd':
# hardship_dpd           1.000000
# last_pymnt_amnt_log    0.622400
# hardship_amount        0.413592
# Name: hardship_dpd, dtype: float64
#
# Top 3 values for column 'orig_projected_additional_accrued_interest':
# orig_projected_additional_accrued_interest    1.000000
# hardship_payoff_balance_amount                0.628904
# interest_per_loan_amnt                        0.600382
# Name: orig_projected_additional_accrued_interest, dtype: float64
#
# Top 3 values for column 'hardship_payoff_balance_amount':
# hardship_payoff_balance_amount    1.00000
# out_prncp_inv                     0.92825
# out_prncp                         0.92824
# Name: hardship_payoff_balance_amount, dtype: float64
#
# Top 3 values for column 'hardship_last_payment_amount':
# hardship_last_payment_amount    1.000000
# last_pymnt_amnt                 0.767869
# last_pymnt_amnt_capped          0.734726
# Name: hardship_last_payment_amount, dtype: float64
#
# Top 3 values for column 'last_pymnt_amnt_log':
# last_pymnt_amnt_log       1.000000
# last_pymnt_amnt_capped    0.695887
# hardship_amount           0.666566
# Name: last_pymnt_amnt_log, dtype: float64
#
# Top 3 values for column 'last_pymnt_amnt_capped':
# last_pymnt_amnt_capped          1.000000
# last_pymnt_amnt                 0.964173
# hardship_last_payment_amount    0.734726
# Name: last_pymnt_amnt_capped, dtype: float64
#
# Top 3 values for column 'loan_id_extracted':
# id                   1.000000
# loan_id_extracted    1.000000
# out_prncp            0.544619
# Name: loan_id_extracted, dtype: float64
#
# Top 3 values for column 'int_rate_clean':
# int_rate_clean            1.000000
# grade_encoded             0.937408
# interest_per_loan_amnt    0.550230
# Name: int_rate_clean, dtype: float64
#
# Top 3 values for column 'term_numeric':
# term_numeric              1.000000
# interest_per_loan_amnt    0.702186
# total_rec_int             0.490884
# Name: term_numeric, dtype: float64
#
# Top 3 values for column 'debt_to_income':
# debt_to_income                    1.000000
# dti                               0.357195
# hardship_payoff_balance_amount    0.284118
# Name: debt_to_income, dtype: float64
#
# Top 3 values for column 'interest_per_loan_amnt':
# interest_per_loan_amnt    1.000000
# loan_amnt                 0.740174
# funded_amnt               0.739952
# Name: interest_per_loan_amnt, dtype: float64
#
# Top 3 values for column 'loan_amnt_log':
# loan_amnt_log    1.000000
# loan_amnt        0.921521
# funded_amnt      0.921318
# Name: loan_amnt_log, dtype: float64
#
# Top 3 values for column 'grade_encoded':
# grade_encoded             1.000000
# int_rate_clean            0.937408
# interest_per_loan_amnt    0.526659
# Name: grade_encoded, dtype: float64

# %% [markdown]
# Key highlights:
# - High correlation (red) is expected across the diagonal (unsurprisingly, features are correlated to themselves..)
# - It is important to review features that are correlated and ask ourselves 2 key questions:
#     > a) Do we understand why they are, in other words is it expected?
#     > b) Do we think a feature may carry additional information to the features it shows high correlation with? If so, it may be worth retaining for modelling purposes, *however* we want to minimise the risk of multicollinearity, which poses a problem for some types of models.
#
# We will be talking about this in our modelling classes, so don't worry too much about it for now.

# %% [markdown]
# ### <span style="color:BLUE"> **>>>EXERCISE:**  </span>
# Looks like there may be some correlation between income and loan amount (expectedly, as higher income individuals are able to afford higher loan amounts).
#
# Search the documentation of [seaborn](seaborn.com) and create a pair plot between those 2 features

# %%
sns.pairplot(df[['loan_amnt', 'annual_inc']])
plt.show()

# %% [markdown]
# 6\. Data standardisation & Normalisation
# ----------------------------------------

# %% [markdown]
# ### Data standardization
# Standardization involves transforming data so that it has a mean of zero and a standard deviation of one. This is particularly important for algorithms that assume data is normally distributed and those that are sensitive to the scale of data, such as:
# 1\. **Gradient descent-based Algorithms:** Algorithms like linear regression, logistic regression, and neural networks.
# 2\. **Distance-based Algorithms:** Algorithms such as K-nearest neighbors (KNN) and K-means clustering, which rely on distance metrics.
#
# ### Data normalization
# Normalization scales data to a range of [0, 1] or [-1, 1]. It's crucial for:
# 1\. **Ensuring Uniform Contribution:** Each feature contributes equally to the model.
# 2\. **Neural Networks:** Where the range of input data can significantly impact the training process.
#
# Standardization is generally preferred when working with algorithms that assume normally distributed data or when features have different units and you need them to have zero mean and unit variance.
# Normalization is typically used when you need to scale features to a fixed range or when working with algorithms sensitive to the magnitude of input data.
#
# Let's take a look at the distribution of two numerical features: `loan_amnt` (loan amount) and `annual_inc` (annual income).

# %%
from sklearn.preprocessing import StandardScaler

# Standardizing the data
scaler = StandardScaler()

df[['loan_amnt_std', 'annual_inc_std']] = scaler.fit_transform(df[['loan_amnt', 'annual_inc']])

# Plotting the distributions before standardization
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['loan_amnt'], bins=30, kde=True)
plt.title('Loan Amount Distribution (Before Standardization)')
plt.subplot(1, 2, 2)
sns.histplot(df['annual_inc'], bins=30, kde=True)
plt.title('Annual Income Distribution (Before Standardization)')
plt.tight_layout()
plt.show()


# Plotting the distributions after standardization
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['loan_amnt_std'], bins=30, kde=True)
plt.title('Loan Amount Distribution (After Standardization)')
plt.subplot(1, 2, 2)
sns.histplot(df['annual_inc_std'], bins=30, kde=True)
plt.title('Annual Income Distribution (After Standardization)')
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalizing the data
scaler = MinMaxScaler()

df[['loan_amnt_norm', 'annual_inc_norm']] = scaler.fit_transform(df[['loan_amnt', 'annual_inc']])

# Plotting the distributions after normalization
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['loan_amnt_norm'], bins=30, kde=True)
plt.title('Loan Amount Distribution (After Normalization)')
plt.subplot(1, 2, 2)
sns.histplot(df['annual_inc_norm'], bins=30, kde=True)
plt.title('Annual Income Distribution (After Normalization)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Use Cases in Lending
#
# #### Credit Risk Analysis
# Standardization and normalization can help improve the accuracy of credit risk models by ensuring that numerical features are on a similar scale, preventing any single feature from disproportionately influencing the model.
#
# #### Fraud Detection
# Standardizing and normalizing transaction amounts can help identify anomalies or unusual patterns that may indicate fraudulent activities.

# %% [markdown]
# 7\. Pandas profiling: a great starting point for EDA
# -------------

# %%
df.head()
# Out:
#           id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0  167338079     4000.0       4000.0           4000.0   36 months   13.08%
# 1   71016917    24000.0      24000.0          24000.0   60 months    9.16%
# 2   39589826     5000.0       5000.0           5000.0   36 months   10.49%
# 3  134798709    24000.0      24000.0          24000.0   60 months   11.05%
# 4  127097355    14000.0      14000.0          14000.0   60 months   13.59%
#
#    installment grade sub_grade       emp_title emp_length home_ownership  \
# 0       134.93     B        B5         cashier  10+ years       MORTGAGE
# 1       500.07     B        B2             ABM    6 years           RENT
# 2       162.49     B        B3          driver  10+ years       MORTGAGE
# 3       522.42     B        B4             NaN        NaN       MORTGAGE
# 4       322.79     C        C2  Shipping Clerk  10+ years       MORTGAGE
#
#    annual_inc verification_status   issue_d loan_status pymnt_plan  \
# 0     48000.0     Source Verified  Mar-2020     Current          n
# 1     57000.0     Source Verified  Feb-2016     Current          n
# 2     55000.0        Not Verified  Jan-2015  Fully Paid          n
# 3     43500.0        Not Verified  Jun-2018     Current          n
# 4     48000.0     Source Verified  Jan-2018  Fully Paid          n
#
#                                                  url             purpose  \
# 0  https://lendingclub.com/browse/loanDetail.acti...    home_improvement
# 1  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 2  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 3  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 4  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
#
#                      title zip_code addr_state    dti  delinq_2yrs  \
# 0         Home improvement    115xx         NY  20.25          1.0
# 1  Credit card refinancing    708xx         LA  25.33          0.0
# 2  Credit card refinancing    347xx         FL   7.22          0.0
# 3       Debt consolidation    443xx         OH  24.55          0.0
# 4       Debt consolidation    681xx         NE  24.30          0.0
#
#   earliest_cr_line  fico_range_low  fico_range_high  inq_last_6mths  \
# 0         Dec-2004           665.0            669.0             0.0
# 1         Jan-2004           680.0            684.0             0.0
# 2         Apr-2010           665.0            669.0             0.0
# 3         Oct-2005           750.0            754.0             0.0
# 4         Apr-2008           735.0            739.0             1.0
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                    19.0                   110.0       4.0      1.0
# 1                     NaN                     NaN      10.0      0.0
# 2                     NaN                    61.0       7.0      1.0
# 3                     NaN                     NaN      15.0      0.0
# 4                     NaN                     NaN      16.0      0.0
#
#    revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0     1988.0      82.8%       12.0                   w    3816.34
# 1    22697.0      64.5%       24.0                   w    4333.29
# 2     6001.0      52.6%        9.0                   f       0.00
# 3     6573.0      12.1%       23.0                   w   16317.69
# 4    11894.0      27.1%       23.0                   w       0.00
#
#    out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0        3816.34    266.950000           266.95           183.66
# 1        4333.29  25496.160000         25496.16         19666.71
# 2           0.00   5846.672836          5846.67          5000.00
# 3       16317.69  12000.930000         12000.93          7682.31
# 4           0.00  16605.680000         16605.68         14000.00
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0          83.29                 0.0         0.0                      0.0
# 1        5829.45                 0.0         0.0                      0.0
# 2         846.67                 0.0         0.0                      0.0
# 3        4318.62                 0.0         0.0                      0.0
# 4        2605.68                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     May-2020           134.93     Jun-2020           May-2020
# 1     May-2020           500.07     Jun-2020           May-2020
# 2     Jan-2018           162.43          NaN           May-2020
# 3     May-2020           522.42     Jun-2020           May-2020
# 4     Jul-2019         11128.82          NaN           Feb-2020
#
#    last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  \
# 0                 669.0                665.0                         1.0
# 1                 704.0                700.0                         0.0
# 2                 789.0                785.0                         0.0
# 3                 749.0                745.0                         0.0
# 4                 779.0                775.0                         0.0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                          NaN          1.0       Individual
# 1                          NaN          1.0       Individual
# 2                          NaN          1.0       Individual
# 3                          NaN          1.0       Individual
# 4                          NaN          1.0       Individual
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                       NaN             0.0
# 1               NaN        NaN                       NaN             0.0
# 2               NaN        NaN                       NaN             0.0
# 3               NaN        NaN                       NaN             0.0
# 4               NaN        NaN                       NaN             0.0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0        3832.0     259024.0          0.0          1.0          0.0
# 1           0.0      61815.0          0.0          3.0          0.0
# 2           0.0     159131.0          NaN          NaN          NaN
# 3           0.0     104590.0          2.0          1.0          0.0
# 4           0.0      90253.0          2.0          2.0          1.0
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          1.0                16.0        9960.0     56.0          0.0
# 1          3.0                14.0       39118.0     72.0          1.0
# 2          NaN                 NaN           NaN      NaN          NaN
# 3          1.0                17.0       11947.0     60.0          2.0
# 4          1.0                 7.0       22953.0     60.0          3.0
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          0.0         0.0      59.0            2400.0     1.0          0.0
# 1          1.0      2137.0      67.0           35200.0     0.0          7.0
# 2          NaN         NaN       NaN           11400.0     NaN          NaN
# 3          3.0      2223.0      25.0           54500.0     2.0          0.0
# 4          4.0      3907.0      43.0           43900.0     1.0          0.0
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           0.0                   1.0      64756.0             NaN      NaN
# 1           0.0                   4.0       6182.0          7741.0     40.5
# 2           NaN                   4.0      22733.0          4521.0     54.8
# 3           2.0                   4.0       6973.0         43140.0     12.0
# 4           2.0                   5.0       5641.0         17318.0     39.9
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                       0.0          0.0               179.0
# 1                       0.0          0.0               145.0
# 2                       0.0          0.0                57.0
# 3                       0.0          0.0                37.0
# 4                       0.0          0.0                72.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                  75.0                   38.0            16.0       2.0
# 1                 137.0                    7.0             7.0       0.0
# 2                  57.0                   14.0             9.0       1.0
# 3                 132.0                    1.0             1.0       2.0
# 4                 117.0                    6.0             6.0       2.0
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                   NaN                      19.0                   16.0
# 1                   7.0                       NaN                   24.0
# 2                  14.0                       NaN                    1.0
# 3                   1.0                       NaN                    3.0
# 4                   6.0                       NaN                    5.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                            19.0                    1.0             0.0
# 1                             NaN                    0.0             3.0
# 2                             NaN                    0.0             3.0
# 3                             NaN                    1.0             6.0
# 4                             NaN                    0.0             4.0
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              2.0          0.0        1.0        5.0            2.0
# 1              5.0          5.0        6.0       15.0            7.0
# 2              5.0          3.0        3.0        2.0            5.0
# 3              7.0         11.0       16.0        2.0           13.0
# 4              5.0          5.0        6.0        5.0           13.0
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0            5.0                  2.0       4.0               0.0
# 1            9.0                  5.0      10.0               0.0
# 2            6.0                  5.0       7.0               0.0
# 3           19.0                  7.0      15.0               0.0
# 4           16.0                  5.0      16.0               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 0.0                 0.0            75.0
# 1           0.0                 0.0                 1.0            95.8
# 2           0.0                 0.0                 1.0           100.0
# 3           0.0                 0.0                 2.0            95.7
# 4           0.0                 0.0                 4.0           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               NaN                   1.0        0.0         395328.0
# 1              60.0                   0.0        0.0          88154.0
# 2              33.3                   0.0        1.0         171118.0
# 3               0.0                   0.0        0.0         202606.0
# 4               0.0                   0.0        0.0         152081.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0            11948.0             0.0                     17928.0
# 1            61815.0         13000.0                     52954.0
# 2            13124.0         10000.0                      7526.0
# 3            18520.0         49000.0                     20000.0
# 4            34847.0         28800.0                     38181.0
#
#    revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
#
#   sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                      NaN                     NaN               NaN
# 1                      NaN                     NaN               NaN
# 2                      NaN                     NaN               NaN
# 3                      NaN                     NaN               NaN
# 4                      NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med hardship_flag hardship_type  \
# 0                                 NaN             N           NaN
# 1                                 NaN             N           NaN
# 2                                 NaN             N           NaN
# 3                                 NaN             N           NaN
# 4                                 NaN             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0             NaN             NaN            NaN              NaN
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
# 3             NaN             NaN            NaN              NaN
# 4             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                 NaN               NaN                     NaN
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              NaN           NaN                  NaN
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
# 3              NaN           NaN                  NaN
# 4              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag hardship_status_filled  \
# 0                           NaN                    N            NO_HARDSHIP
# 1                           NaN                    N            NO_HARDSHIP
# 2                           NaN                    N            NO_HARDSHIP
# 3                           NaN                    N            NO_HARDSHIP
# 4                           NaN                    N            NO_HARDSHIP
#
#    last_pymnt_amnt_log  last_pymnt_amnt_capped  loan_id_extracted  \
# 0             4.912140                  134.93          167338079
# 1             6.216746                  500.07           71016917
# 2             5.096385                  162.43           39589826
# 3             6.260384                  522.42          134798709
# 4             9.317383                11128.82          127097355
#
#   emp_title_clean emp_title_manager Job Title Category  int_rate_clean  \
# 0         cashier             False       NaN      NaN          0.1308
# 1             abm             False       NaN      NaN          0.0916
# 2          driver             False       NaN      NaN          0.1049
# 3             NaN               NaN       NaN      NaN          0.1105
# 4  shipping clerk             False       NaN      NaN          0.1359
#
#    term_numeric  debt_to_income  interest_per_loan_amnt  loan_amnt_log  \
# 0          36.0        0.083333                  15.696       8.294300
# 1          60.0        0.421053                 109.920      10.085851
# 2          36.0        0.090909                  15.735       8.517393
# 3          60.0        0.551724                 132.600      10.085851
# 4          60.0        0.291667                  95.130       9.546884
#
#    grade_encoded  loan_amnt_std  annual_inc_std
# 0              1      -1.196895       -0.367206
# 1              1       0.915452       -0.264024
# 2              1      -1.091278       -0.286953
# 3              1       0.915452       -0.418798
# 4              2      -0.140722       -0.367206

# %%
# Sampling data for ease of processing (note: make sure the sample size is large enough to extrapolate from)
features = ['term', 'fico_range_high', 'fico_range_low', 'annual_inc', 'dti']
df_sampled = df[features].sample(100)

# %%
#import sys
#!{sys.executable} -m pip install -U ydata-profiling[notebook]
#!pip install jupyter-contrib-nbextensions

from ydata_profiling import ProfileReport
report = ProfileReport(df_sampled, title= "Report")
report # Will take a few minutes to process

# report.to_file('../reports/dsif3-data-profiling.html') # To save as html
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.12.2&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-02-23 23:39:13.288364&quot;&gt;&lt;title&gt;Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %% [markdown]
# ## Data export
# Before moving to the last section on time series, let's export our data to the "intermediate" data folder.

# %%
df.to_csv(f"{path_python_material}/data/2-intermediate/df_out_dsif3.csv"
                        , index = False)

# %% [markdown]
# 8\. Assignment #1
# -------------
#
# Take your data cleaning and exploratory data analysis further and uncover **at least 2 additional actionable insights** as an outcome of EDA.
# Tips:
# - Feel free to drop or generate additional features in doing so.
# - How can the business leverage the insights uncovered and how can the impact of your insight be measured?
#
# **Submission:** Submit your notebook with the EDA and insights documented.
#
# **Evaluation Criteria:**
#
# -   Depth of analysis and insights derived.
# -   Relevance and feasibility of the actionable insights.
# -   Clarity and thoroughness of code and explanations.
#
# Tips: don't be afraid to be creative, and go past what was covered in this session (e.g. additional plot types etc.)
#
# Happy exploring!

# %%
#### Example structure ####

# 1. Load data 

df.head(3)
# Out:
#           id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0  167338079     4000.0       4000.0           4000.0   36 months   13.08%
# 1   71016917    24000.0      24000.0          24000.0   60 months    9.16%
# 2   39589826     5000.0       5000.0           5000.0   36 months   10.49%
#
#    installment grade sub_grade emp_title emp_length home_ownership  \
# 0       134.93     B        B5   cashier  10+ years       MORTGAGE
# 1       500.07     B        B2       ABM    6 years           RENT
# 2       162.49     B        B3    driver  10+ years       MORTGAGE
#
#    annual_inc verification_status   issue_d loan_status pymnt_plan  \
# 0     48000.0     Source Verified  Mar-2020     Current          n
# 1     57000.0     Source Verified  Feb-2016     Current          n
# 2     55000.0        Not Verified  Jan-2015  Fully Paid          n
#
#                                                  url           purpose  \
# 0  https://lendingclub.com/browse/loanDetail.acti...  home_improvement
# 1  https://lendingclub.com/browse/loanDetail.acti...       credit_card
# 2  https://lendingclub.com/browse/loanDetail.acti...       credit_card
#
#                      title zip_code addr_state    dti  delinq_2yrs  \
# 0         Home improvement    115xx         NY  20.25          1.0
# 1  Credit card refinancing    708xx         LA  25.33          0.0
# 2  Credit card refinancing    347xx         FL   7.22          0.0
#
#   earliest_cr_line  fico_range_low  fico_range_high  inq_last_6mths  \
# 0         Dec-2004           665.0            669.0             0.0
# 1         Jan-2004           680.0            684.0             0.0
# 2         Apr-2010           665.0            669.0             0.0
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                    19.0                   110.0       4.0      1.0
# 1                     NaN                     NaN      10.0      0.0
# 2                     NaN                    61.0       7.0      1.0
#
#    revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0     1988.0      82.8%       12.0                   w    3816.34
# 1    22697.0      64.5%       24.0                   w    4333.29
# 2     6001.0      52.6%        9.0                   f       0.00
#
#    out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0        3816.34    266.950000           266.95           183.66
# 1        4333.29  25496.160000         25496.16         19666.71
# 2           0.00   5846.672836          5846.67          5000.00
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0          83.29                 0.0         0.0                      0.0
# 1        5829.45                 0.0         0.0                      0.0
# 2         846.67                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     May-2020           134.93     Jun-2020           May-2020
# 1     May-2020           500.07     Jun-2020           May-2020
# 2     Jan-2018           162.43          NaN           May-2020
#
#    last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  \
# 0                 669.0                665.0                         1.0
# 1                 704.0                700.0                         0.0
# 2                 789.0                785.0                         0.0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                          NaN          1.0       Individual
# 1                          NaN          1.0       Individual
# 2                          NaN          1.0       Individual
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                       NaN             0.0
# 1               NaN        NaN                       NaN             0.0
# 2               NaN        NaN                       NaN             0.0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0        3832.0     259024.0          0.0          1.0          0.0
# 1           0.0      61815.0          0.0          3.0          0.0
# 2           0.0     159131.0          NaN          NaN          NaN
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          1.0                16.0        9960.0     56.0          0.0
# 1          3.0                14.0       39118.0     72.0          1.0
# 2          NaN                 NaN           NaN      NaN          NaN
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          0.0         0.0      59.0            2400.0     1.0          0.0
# 1          1.0      2137.0      67.0           35200.0     0.0          7.0
# 2          NaN         NaN       NaN           11400.0     NaN          NaN
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           0.0                   1.0      64756.0             NaN      NaN
# 1           0.0                   4.0       6182.0          7741.0     40.5
# 2           NaN                   4.0      22733.0          4521.0     54.8
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                       0.0          0.0               179.0
# 1                       0.0          0.0               145.0
# 2                       0.0          0.0                57.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                  75.0                   38.0            16.0       2.0
# 1                 137.0                    7.0             7.0       0.0
# 2                  57.0                   14.0             9.0       1.0
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                   NaN                      19.0                   16.0
# 1                   7.0                       NaN                   24.0
# 2                  14.0                       NaN                    1.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                            19.0                    1.0             0.0
# 1                             NaN                    0.0             3.0
# 2                             NaN                    0.0             3.0
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              2.0          0.0        1.0        5.0            2.0
# 1              5.0          5.0        6.0       15.0            7.0
# 2              5.0          3.0        3.0        2.0            5.0
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0            5.0                  2.0       4.0               0.0
# 1            9.0                  5.0      10.0               0.0
# 2            6.0                  5.0       7.0               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 0.0                 0.0            75.0
# 1           0.0                 0.0                 1.0            95.8
# 2           0.0                 0.0                 1.0           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               NaN                   1.0        0.0         395328.0
# 1              60.0                   0.0        0.0          88154.0
# 2              33.3                   0.0        1.0         171118.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0            11948.0             0.0                     17928.0
# 1            61815.0         13000.0                     52954.0
# 2            13124.0         10000.0                      7526.0
#
#    revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
#
#   sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                      NaN                     NaN               NaN
# 1                      NaN                     NaN               NaN
# 2                      NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med hardship_flag hardship_type  \
# 0                                 NaN             N           NaN
# 1                                 NaN             N           NaN
# 2                                 NaN             N           NaN
#
#   hardship_reason hardship_status  deferral_term  hardship_amount  \
# 0             NaN             NaN            NaN              NaN
# 1             NaN             NaN            NaN              NaN
# 2             NaN             NaN            NaN              NaN
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                 NaN               NaN                     NaN
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
#
#    hardship_length  hardship_dpd hardship_loan_status  \
# 0              NaN           NaN                  NaN
# 1              NaN           NaN                  NaN
# 2              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag hardship_status_filled  \
# 0                           NaN                    N            NO_HARDSHIP
# 1                           NaN                    N            NO_HARDSHIP
# 2                           NaN                    N            NO_HARDSHIP
#
#    last_pymnt_amnt_log  last_pymnt_amnt_capped  loan_id_extracted  \
# 0             4.912140                  134.93          167338079
# 1             6.216746                  500.07           71016917
# 2             5.096385                  162.43           39589826
#
#   emp_title_clean emp_title_manager Job Title Category  int_rate_clean  \
# 0         cashier             False       NaN      NaN          0.1308
# 1             abm             False       NaN      NaN          0.0916
# 2          driver             False       NaN      NaN          0.1049
#
#    term_numeric  debt_to_income  interest_per_loan_amnt  loan_amnt_log  \
# 0          36.0        0.083333                  15.696       8.294300
# 1          60.0        0.421053                 109.920      10.085851
# 2          36.0        0.090909                  15.735       8.517393
#
#    grade_encoded  loan_amnt_std  annual_inc_std
# 0              1      -1.196895       -0.367206
# 1              1       0.915452       -0.264024
# 2              1      -1.091278       -0.286953

# %%
# 2. Data cleaning
df['term_numeric'] = df['term'].str.strip(" months").astype("float") 
df['term_numeric'].head(5)

df['int_rate_clean'] = df['int_rate'].str.rstrip('%').astype('float') / 100.0
df['int_rate_clean'].head(5)

df['emp_length_clean'] = df['emp_length'].str.strip(" years") #.astype("float") 
df['emp_length_clean'].head(5)

df['emp_length_clean'] = df['emp_length'].str.strip(" years").str.replace('+', '', regex=False)

# Step 2: Convert to numeric (NaN for non-numeric values)
df['emp_length_clean'] = pd.to_numeric(df['emp_length_clean'], errors='coerce')

# Step 3: Handle missing values (optional)
df['emp_length_clean'] = df['emp_length_clean'].fillna(0)  # Replace NaN with 0

# Display the cleaned column
print(df['emp_length_clean'].head())
# Out:
# 0    10.0
# 1     6.0
# 2    10.0
# 3     0.0
# 4    10.0
# Name: emp_length_clean, dtype: float64

# %%
# 3. Summary statistics
summary_statistics(df,'emp_length_clean')
# Out:
# Mean Loan Amount: 5.41735
# Median Loan Amount: 5.0
# Mode Loan Amount: 10.0
# Standard Deviation of Loan Amount: 3.910465687730676
# Loan Amount Percentiles:
# 0.25     2.0
# 0.50     5.0
# 0.75    10.0
# Name: emp_length_clean, dtype: float64
# Skewness: -0.052702340478488874
# Skewness < 0: Negative skew (left skew).
# -------------------------------------

# %%
# 4. Feature engineering
correlation_term_and_emp_leng = df['loan_amnt'].corr(df['emp_length_clean'])
print(f"Correlation between loan amount and emp_length: {correlation_term_and_emp_leng}")
# Out:
# Correlation between loan amount and emp_length: 0.09302466239953065

# %%
df['loan_amnt_to_emp_leng'] = df['loan_amnt'] / df['emp_length_clean']
df[['id','loan_amnt', 'emp_length_clean', 'loan_amnt_to_emp_leng']].head(5)
# Out:
#           id  loan_amnt  emp_length_clean  loan_amnt_to_emp_leng
# 0  167338079     4000.0              10.0                  400.0
# 1   71016917    24000.0               6.0                 4000.0
# 2   39589826     5000.0              10.0                  500.0
# 3  134798709    24000.0               0.0                    inf
# 4  127097355    14000.0              10.0                 1400.0

# %%
# 5. Visualization 
sns.scatterplot(x='loan_amnt', y='loan_amnt_to_emp_leng', data=df)
plt.title('Scatter Plot of Loan Amount vs Annual Income')
plt.xlabel('Loan Amount')
plt.ylabel('Annual Income')
plt.show()


sns.jointplot(x='loan_amnt', y='loan_amnt_to_emp_leng', data=df, kind='scatter')
plt.suptitle('Joint Plot of Loan Amount vs Annual Income')
plt.show()

# %%
# 6. Insights and conclusions
#    > what actions is your insight driving 
#    (could be data cleaning action, or a question/hypothesis for the business to test, etc.)
There is weak correlation between loan_amnt and emp_leng years, (0.09)
but i think it need more deeple research coz i see some patterns at my plots

# %% [markdown]
# # End of session

# %%
from IPython.display import Image
Image(filename='../images/the-end.jpg', width=500,)
